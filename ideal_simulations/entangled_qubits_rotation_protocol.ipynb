# %%
import numpy as np
from qiskit import *
from qiskit.quantum_info import Statevector
from qiskit_aer import AerSimulator
from IPython.display import display, Math, Latex
from math import pi, sqrt
import matplotlib.pyplot as plt

# %%
# rotations = how many rotation steps
rotations = 200

# numShots = how many times to run each circuit
numShots = 4096

# d = phase difference
d = 0
entangled_state = [1/sqrt(2), 0, 0, np.exp(1j*d)/sqrt(2)]

x_val = []
y_val = [[], [], [], []]
states = ['H', 'D', 'V', 'A']

qc = QuantumCircuit(2, 2)
state = ''

for i in range(4):
    
    for j in range(rotations):
        # build the circuit
        qc.clear()
        qc = QuantumCircuit(2, 2)
        qc.initialize(entangled_state, [0, 1])

        # display the state for the first time
        if i + j == 0:
            display(Statevector(qc).draw(output='latex'))
            state = Statevector(qc).draw(output='latex_source')
        
        # keep A the same, and rotate B
        qc.ry(i*pi/2, 0)
        delta = 4*j*pi/rotations
        qc.ry(delta, 1)
        qc.measure([0, 1], [0, 1])
        if i + j == 0:
            display(qc.draw(output='mpl'))

        # simulate
        backend = AerSimulator(method='statevector')
        job = backend.run(transpile(qc, backend), shots=numShots)
        result = job.result()
        counts = result.get_counts(qc)

        # put in a zero for the count if needed
        if '00' in counts:
            out0 = counts['00']
        else:
            out0 = 0 
            
        if i == 0:
            x_val.append(delta)
        
        y_val[i].append(out0)

fig, ax = plt.subplots()

for i in range(4):
    ax.plot(x_val, y_val[i], label=states[i])
    
ax.set_xlabel('Polarizer Angle')
ax.set_ylabel('Counts')
ax.set_ylim(0 - 40, numShots + 40)
x_ticks = ax.set_xticks([0, pi, 2*pi, 3*pi, 4*pi], ['0', 'π', '2π', '3π', '4π'])
legend = plt.legend()
plt.title('$' + state + '$')
plt.savefig('plots\\entangled_qubits\\polarization_correlation_d=0')
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |11\rangle$$
